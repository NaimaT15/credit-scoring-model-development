# %%
import pandas as pd
import sys
import os

# Add the scripts directory to the Python path
sys.path.append(os.path.abspath('../scripts'))

# %% [markdown]
# # Overview of the Data and Summary Statistics

# %%
# Importing the functions from the script file
from EDA import calculate_central_tendency_dispersion, load_dataset, display_head, get_shape, get_info, get_summary_statistics

# Load the dataset
file_path = r'C:\Users\Naim\credit-scoring-model-development\data\data.csv'
data = load_dataset(file_path)

# Display the first few rows
print("First few rows of the dataset:")
print(display_head(data))

# Get the shape of the dataset
print("\nNumber of rows and columns:")
print(get_shape(data))

# Get information about data types and missing values
print("\nDataset Information:")
get_info(data)

# Get summary statistics of numerical columns
print("\nSummary Statistics:")
print(get_summary_statistics(data))
# Calculate Central Tendency and Dispersion
print("Central Tendency and Dispersion Metrics:")
central_dispersion_metrics = calculate_central_tendency_dispersion(data)
print(central_dispersion_metrics)
# Out:
# First few rows of the dataset:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %% [markdown]
# # Distribution of Numerical Features

# %%
from EDA import plot_numerical_distributions
# Visualize the distribution of numerical features
print("Visualizing the distribution of numerical features:")
plot_numerical_distributions(data)
# Out:
# Visualizing the distribution of numerical features:

# %% [markdown]
# # Distribution of Categorical Features

# %%
from EDA import plot_categorical_distributions
print("Visualizing the distribution of categorical features:")
plot_categorical_distributions(data, top_n=10)
# Out:
# Visualizing the distribution of categorical features:
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:100: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:100: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:100: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Correlation Analysis

# %%
from EDA import correlation_analysis
correlation_analysis(data)
# Out:
# Correlation Matrix:
#                   CountryCode    Amount     Value  PricingStrategy  FraudResult
# CountryCode              NaN       NaN       NaN              NaN          NaN
# Amount                   NaN  1.000000  0.989692        -0.061931     0.557370
# Value                    NaN  0.989692  1.000000        -0.017020     0.566739
# PricingStrategy          NaN -0.061931 -0.017020         1.000000    -0.033821
# FraudResult              NaN  0.557370  0.566739        -0.033821     1.000000

# %% [markdown]
# # Identifying Missing Values

# %%
from EDA import identify_missing_values
print("Analyzing Missing Values:")
missing_data_info = identify_missing_values(data)
# Out:
# Analyzing Missing Values:
# Columns with Missing Values:
#  Empty DataFrame
# Columns: [Column, Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# #

# %%
from EDA import detect_outliers
# Detect and visualize outliers in the dataset
print("Detecting Outliers in Numerical Features:")
detect_outliers(data)
# Out:
# Detecting Outliers in Numerical Features:
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:171: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=numeric_data[col], palette='viridis')
# CountryCode: 0 outliers detected.
# Outliers range below 256.00 or above 256.00.
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:171: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=numeric_data[col], palette='viridis')
# Amount: 24441 outliers detected.
# Outliers range below -4325.00 or above 7075.00.
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:171: FutureWarning:
#
# ...

# %%
from EDA import fill_outliers
# Columns to fill outliers for
columns_to_fill = ['Amount', 'Value', 'PricingStrategy', 'FraudResult']

# Fill outliers in the specified columns
data_filled = fill_outliers(data, columns=columns_to_fill)

# Check the changes in the dataset
print("Dataset after filling outliers:")
print(data_filled[columns_to_fill].describe())
# Out:
# Column 'Amount': Outliers filled using capping method with lower bound = -4325.00 and upper bound = 7075.00.
# Column 'Value': Outliers filled using capping method with lower bound = -6812.50 and upper bound = 12087.50.
# Column 'PricingStrategy': Outliers filled using capping method with lower bound = 2.00 and upper bound = 2.00.
# Column 'FraudResult': Outliers filled using capping method with lower bound = 0.00 and upper bound = 0.00.
# Dataset after filling outliers:
#              Amount         Value  PricingStrategy  FraudResult
# count  95662.000000  95662.000000          95662.0      95662.0
# mean    1449.051201   3403.667282              2.0          0.0
# std     3210.808287   4168.243292              0.0          0.0
# min    -4325.000000      2.000000              2.0          0.0
# 25%      -50.000000    275.000000              2.0          0.0
# 50%     1000.000000   1000.000000              2.0          0.0
# ...

# %%
from EDA import detect_outliers
# Detect and visualize outliers in the dataset
print("Detecting Outliers in Numerical Features:")
detect_outliers(data)
# Out:
# Detecting Outliers in Numerical Features:
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:165: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=numeric_data[col], palette='viridis')
# CountryCode: 0 outliers detected.
# Outliers range below 256.00 or above 256.00.
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:165: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=numeric_data[col], palette='viridis')
# Amount: 0 outliers detected.
# Outliers range below -4325.00 or above 7075.00.
# c:\Users\Naim\credit-scoring-model-development\scripts\EDA.py:165: FutureWarning:
#
# ...

# %%
from EDA import create_advanced_aggregate_features
customer_advanced_features = create_advanced_aggregate_features(data)

# Display the first few rows of the aggregated feature set
print("Customer Advanced Aggregate Features:")
print(customer_advanced_features.head())
# Out:
# Advanced aggregate features created successfully for each customer.
# Customer Advanced Aggregate Features:
#         CustomerId  Total_Transaction_Amount  Average_Transaction_Amount  \
# 0     CustomerId_1                  -10000.0               -10000.000000
# 1    CustomerId_10                  -10000.0               -10000.000000
# 2  CustomerId_1001                   20000.0                 4000.000000
# 3  CustomerId_1002                    4225.0                  384.090909
# 4  CustomerId_1003                   20000.0                 3333.333333
#
#    Transaction_Count  Std_Dev_Transaction_Amount  Max_Transaction_Amount  \
# 0                  1                    0.000000                -10000.0
# 1                  1                    0.000000                -10000.0
# 2                  5                 6558.963333                 10000.0
# 3                 11                  560.498966                  1500.0
# ...
